# %% [markdown]
# <a href="https://colab.research.google.com/github/Tezashree/DataScienceBootcamp/blob/main/classNotes/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
X = 6 * np.random.rand(200, 1) - 3
y =  0.8 * X ** 2 + 0.9*X +2 + np.random.randn(200,1)
plt.plot(X, y, 'b.')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size= .2)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
plt.plot(X,y, 'b.')
plt.plot(X_train,model.predict(X_train), 'r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=9)
x_train_trans = poly.fit_transform(X_train)
x_test_trans = poly.transform(X_test)

model_poly = LinearRegression()
model_poly.fit(x_train_trans, y_train)
y_pred = model_poly.predict(x_test_trans)

plt.plot(X, y, 'b.')
plt.plot(X_test, y_pred)
plt.plot(sorted(X_test), sorted(y_pred), color='red')
plt.show()
